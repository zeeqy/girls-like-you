# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Q3 SF = 1

# %%
rs = [0.0083, 0.0776, 0.8219 ,8.2854]
eo = [0.0459,0.5474,4.8121,48.6976]
ew = [5.4626,6.6124,7.7871,14.8590]
fj = [25.91,25.91,25.91,25.91]
x = [1,2,3,4]
plt.figure(figsize=(8,6))
plt.plot(x, rs,'-',linewidth=3.0,marker="^",markersize=15)
plt.plot(x, eo,'-',linewidth=3.0,marker="o",markersize=15)
plt.plot(x, ew,'-',linewidth=3.0,marker="s",markersize=15)
plt.plot(x, fj,'-',linewidth=3.0,marker="*",markersize=18)
plt.xticks([1,2,3,4], ("$10^3$", "$10^4$", "$10^5$", "$10^6$"))
plt.ylim(0.001,10000)
plt.yticks([0.001,0.01,0.1,1,10,100,1000,10000], ("$10^-3$", "$10^-2$", "$10^-1$", "$10^0$","$10^1$","$10^2$","$10^3$","$10^4$"))
plt.yscale('log')
plt.ylabel('time(seconds)',fontsize=20)
plt.xlabel('number of samples collected',fontsize=20)
plt.legend(['Reverse Sample','Extened Olken', 'Exact Weight', 'Full Join'],loc='upper left',fontsize=15.5)
plt.savefig('Q3_1x.eps',format='eps', dpi=1200)
plt.show()

# %% [markdown]
# ### QX SF = 1

# %%
font = {'family': 'sans-serif',
        'color':  'black',
        'weight': 'normal',
        'size': 16,
        }

eo = [0.0905,0.7555,6.2620,63.0996]
ew = [5.7445,5.4772,7.5107,16.6983]
fj = [3227.6410,3227.6410,3227.6410,3227.6410]
x = [1,2,3,4]
plt.figure(figsize=(8,6))
plt.plot(x, eo,'-',linewidth=3.0,marker="o",color='#ff7f0e',markersize=15)
plt.plot(x, ew,'-',linewidth=3.0,marker="s",color='#2ca02c',markersize=15)
plt.plot(x, fj,'-',linewidth=3.0,marker="*",markersize=18, color='#d62728')
plt.xticks([1,2,3,4], ("$10^3$", "$10^4$", "$10^5$", "$10^6$"))
plt.ylim(0.001,10000)
plt.yticks([0.001,0.01,0.1,1,10,100,1000,10000], ("$10^-3$", "$10^-2$", "$10^-1$", "$10^0$","$10^1$","$10^2$","$10^3$","$10^4$"))
plt.yscale('log')
plt.ylabel('time(seconds)',fontsize=20)
plt.xlabel('number of samples collected',fontsize=20)
plt.legend(['Extened Olken', 'Exact Weight','Full Join'],loc='lower right',fontsize=15.5)
plt.savefig('QX_1x.eps',format='eps', dpi=1200)

# %% [markdown]
# ### Q3 SF = 10

# %%
rs = [0.0149,0.1086,1.1440,9.3217]
eo = [0.0814,0.6557,5.9953,59.4954]
ew = [120.6532,117.3384,100.5332,111.8499]
fj = [140.7249,140.7249,140.7249,140.7249]
x = [1,2,3,4]
plt.figure(figsize=(8,6))
plt.plot(x, rs,'-',linewidth=3.0,marker="^",markersize=15)
plt.plot(x, eo,'-',linewidth=3.0,marker="o",markersize=15)
plt.plot(x, ew,'-',linewidth=3.0,marker="s",markersize=15)
plt.plot(x, fj,'-',linewidth=3.0,marker="*",markersize=18)
plt.xticks([1,2,3,4], ("$10^3$", "$10^4$", "$10^5$", "$10^6$"))
plt.ylim(0.001,10000)
plt.yticks([0.001,0.01,0.1,1,10,100,1000,10000], ("$10^-3$", "$10^-2$", "$10^-1$", "$10^0$","$10^1$","$10^2$","$10^3$","$10^4$"))
plt.yscale('log')
plt.ylabel('time(seconds)',fontsize=20)
plt.xlabel('number of samples collected',fontsize=20)
plt.legend(['Reverse Sample','Extened Olken', 'Exact Weight', 'Full Join'],loc='lower right',fontsize=15.5)
plt.savefig('Q3_10x.eps',format='eps', dpi=1200)

# %% [markdown]
# ### QX SF = 10

# %%
font1 = {'family': 'sans-serif',
        'color':  '#d62728',
        'weight': 'normal',
        'size': 20,
        }
font2 = {'family': 'sans-serif',
        'color':  'black',
        'weight': 'normal',
        'size': 20,
        }

eo = [0.0867,0.8463,8.2735,77.0783]
ew = [138.0665, 93.4698, 120.0298,125.1986]
x = [1,2,3,4]
plt.figure(figsize=(8,6))
plt.plot(x, eo,'-',linewidth=3.0,marker="o",color='#ff7f0e',markersize=15)
plt.plot(x, ew,'-',linewidth=3.0,marker="s",color='#2ca02c',markersize=15)
plt.text(1,1000,'★',fontdict=font1)
plt.plot([], [], '-',linewidth=3.0,marker="*",markersize=18,color='#d62728')
plt.text(1.15,1000,': timeout',fontdict=font2)
plt.xticks([1,2,3,4], ("$10^3$", "$10^4$", "$10^5$", "$10^6$"))
plt.ylim(0.001,10000)
plt.yticks([0.001,0.01,0.1,1,10,100,1000,10000], ("$10^-3$", "$10^-2$", "$10^-1$", "$10^0$","$10^1$","$10^2$","$10^3$","$10^4$"))
plt.yscale('log')
plt.ylabel('time(seconds)',fontsize=20)
plt.xlabel('number of samples collected',fontsize=20)
plt.legend(['Extened Olken', 'Exact Weight','Full Join'],loc='lower right',fontsize=15.5)
plt.savefig('QX_10x.eps',format='eps', dpi=1200)
